# %% [raw]
# ---
# description: File **cost_calculation.py** will contain all of the cost calculation
#   functions
# output-file: cost_calculations.html
# title: cost_calculations
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(cost_calc_monthly_cost_table)
# Out:
# ---
#
# [source](https://github.com/mohitshrestha/emailleadscoring/blob/main/emailleadscoring/cost_calculations.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### cost_calc_monthly_cost_table
#
# >      cost_calc_monthly_cost_table (email_list_size=100000.0,
# >                                    email_list_growth_rate=0.035,
# >                                    sales_emails_per_month=5,
# >                                    unsub_rate_per_sales_email=0.005,
# >                                    customer_conversion_rate=0.05,
# >                                    average_customer_value=2000, n_periods=12)
#
# This function generates a Cost Table.
# Args:
#     email_list_size (_type_, optional): Email list size. Defaults to 1e5.
#     email_list_growth_rate (float, optional): Monthly email list growth rate. Defaults to 0.035.
#     sales_emails_per_month (int, optional): Sales email per month. Defaults to 5.
# ...

# %%
#| echo: false
#| output: asis
show_doc(cost_total_unsub_cost)
# Out:
# ---
#
# [source](https://github.com/mohitshrestha/emailleadscoring/blob/main/emailleadscoring/cost_calculations.py#L74){target="_blank" style="float:right; font-size:smaller"}
#
# ### cost_total_unsub_cost
#
# >      cost_total_unsub_cost (cost_table)
#
# Takes the input from cost_calc_monthly_cost_table(), and produces a summary of the total costs.
# Args:
#     cost_table (DataFrame): Output fro cost_calc_monthly_cost_table()
#
# Returns:
#     DataFrame: Summarized total costs for email unsubscription.

# %%
#| echo: false
#| output: asis
show_doc(cost_simulate_unsub_costs)
# Out:
# ---
#
# [source](https://github.com/mohitshrestha/emailleadscoring/blob/main/emailleadscoring/cost_calculations.py#L89){target="_blank" style="float:right; font-size:smaller"}
#
# ### cost_simulate_unsub_costs
#
# >      cost_simulate_unsub_costs (email_list_monthly_growth_rate=[0, 0.035],
# >                                 customer_conversion_rate=[0.04, 0.05, 0.06],
# >                                 **kwargs)
#
# Generate a cost analysis simulation to characterize cost uncertainty.
#
# Args:
#     email_list_monthly_growth_rate (list, optional): List of values for email monthly growth rate to simulate. Defaults to [0, 0.035].
#     customer_conversion_rate (list, optional): List of values for customer conversion rate to simulate. Defaults to [0.04, 0.05, 0.06].
#
# Returns:
#     DataFrame: Cartesian Product of email list and customer conversion rate is calculated and total unsubscriber costs are calculated.

# %%
#| echo: false
#| output: asis
show_doc(cost_plot_simulated_unsub_costs)
# Out:
# ---
#
# [source](https://github.com/mohitshrestha/emailleadscoring/blob/main/emailleadscoring/cost_calculations.py#L137){target="_blank" style="float:right; font-size:smaller"}
#
# ### cost_plot_simulated_unsub_costs
#
# >      cost_plot_simulated_unsub_costs (simulation_results)
#
# A plottign function to plot the results from cost_simulate_unsub_costs() function.
#
# Args:
#     simulation_results (DataFrame): The output from cost_simulate_unsub_costs()
#
# Returns:
#     Plotly Plot: Heatmap that visualizes the cost simulation.
